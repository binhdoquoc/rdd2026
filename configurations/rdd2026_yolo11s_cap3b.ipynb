# %%
# THIS CELL MUST COME ON TOP
import os
# MAKE SURE TO SELECT GPU CORE APPROPRAITELY and AVOID RUNNING TWO TRAINING ON ONE DEVICE
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Optional: can reduce fragmentation-related OOM issues
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
import os
import torch
os.chdir("/home/mdptlab/roaddamagedetector/yolov11")
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO
model_name = "yolo11s_cap3b"
ls = 0.0
# Build a YOLOv11l model from pretrained weight
model = YOLO(f"{model_name}.yaml")
model.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 5
#       3 ls = 0.0
#       4 # Build a YOLOv11l model from pretrained weight
# ----> 5 model = YOLO(f"{model_name}.yaml")
#       6 model.info()
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/ultralytics/models/yolo/model.py:78, in YOLO.__init__(self, model, task, verbose)
#      75     self.__dict__ = new_instance.__dict__
#      76 else:
#      77     # Continue with default YOLO initialization
# ---> 78     super().__init__(model=model, task=task, verbose=verbose)
#      79     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      80         from ultralytics import RTDETR
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/ultralytics/engine/model.py:142, in Model.__init__(self, model, task, verbose)
#     140 __import__("os").environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"  # to avoid deterministic warnings
#     141 if str(model).endswith((".yaml", ".yml")):
# --> 142     self._new(model, task=task, verbose=verbose)
#     143 else:
#     144     self._load(model, task=task)
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/ultralytics/engine/model.py:250, in Model._new(self, cfg, task, model, verbose)
#     248 self.cfg = cfg
#     249 self.task = task or guess_model_task(cfg_dict)
# --> 250 self.model = (model or self._smart_load("model"))(cfg_dict, verbose=verbose and RANK == -1)  # build model
#     251 self.overrides["model"] = self.cfg
#     252 self.overrides["task"] = self.task
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/ultralytics/nn/tasks.py:401, in DetectionModel.__init__(self, cfg, ch, nc, verbose)
#     392 """Initialize the YOLO detection model with the given config and parameters.
#     393
#     394 Args:
#    (...)
#     398     verbose (bool): Whether to display model information.
#     399 """
#     400 super().__init__()
# --> 401 _initialize_yolo_model(self, cfg, ch, nc, verbose)
#     403 # Build strides
#     404 m = self.model[-1]  # Detect()
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/ultralytics/nn/tasks.py:358, in _initialize_yolo_model(model, cfg, ch, nc, verbose)
#     356     LOGGER.info(f"Overriding model.yaml nc={model.yaml['nc']} with nc={nc}")
#     357     model.yaml["nc"] = nc  # override YAML value
# --> 358 model.model, model.save = parse_model(deepcopy(model.yaml), ch=ch, verbose=verbose)  # model, savelist
#     359 model.names = {i: f"{i}" for i in range(model.yaml["nc"])}  # default names dict
#     360 model.inplace = model.yaml.get("inplace", True)
#
# File ~/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/ultralytics/nn/tasks.py:1738, in parse_model(d, ch, verbose)
#    1713 repeat_modules = frozenset(  # modules with 'repeat' arguments
#    1714     {
#    1715         BottleneckCSP,
#    (...)
#    1730     }
#    1731 )
#    1732 for i, (f, n, m, args) in enumerate(d["backbone"] + d["head"]):  # from, number, module, args
#    1733     m = (
#    1734         getattr(torch.nn, m[3:])
#    1735         if "nn." in m
#    1736         else getattr(__import__("torchvision").ops, m[16:])
#    1737         if "torchvision.ops." in m
# -> 1738         else globals()[m]
#    1739     )  # get module
#    1740     for j, a in enumerate(args):
#    1741         if isinstance(a, str):
#
# KeyError: 'CoordAtt'

# %%
# Load pretrained weights
model = model.load("yolo11s.pt")

# %%
def format_float(value):
    # Multiply by 100 to shift the decimal and convert to int
    scaled_value = int(value * 100)
    # Format as a 3-digit zero-padded string
    return f"{scaled_value:03d}"

# %%
# Training.
results = model.train(
   data='/home/pham/Documents/SHSU/Researching/roaddamagedetector/rddallcountriespotholesfortrainyolov11.yaml',
   imgsz=640,
   epochs=150,
   batch=32,
   label_smoothing_mode="none",
   name=f"{model_name}")
# Out:
# New https://pypi.org/project/ultralytics/8.4.61 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.60 🚀 Python-3.10.20 torch-2.5.1+cu121 CUDA:0 (NVIDIA RTX A4000, 15985MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_label_smoothing=0.0, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cp_label_smoothing=0.0, cutmix=0.0, data=/home/pham/Documents/SHSU/Researching/roaddamagedetector/rddallcountriespotholesfortrainyolov11.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=150, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, label_smoothing_mode=none, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s_p2p3p4p5.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo11s_p2p3p4p5, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=yolo11s.pt, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/pham/Documents/SHSU/Researching/roaddamagedetector/yolov11/runs/detect/yolo11s_p2p3p4p5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  18             [-1, 2]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  20                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  21            [-1, 16]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  23                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  24            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  25                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  26                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  27            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  28                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  29    [19, 22, 25, 28]  1    811360  ultralytics.nn.modules.head.Detect           [4, 16, None, [64, 128, 256, 512]]
# YOLO11s_p2p3p4p5 summary: 217 layers, 9,575,552 parameters, 9,575,536 gradients, 29.0 GFLOPs
#
# Transferred 525/593 items from pretrained weights
# Freezing layer 'model.29.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2311.6±717.0 MB/s, size: 155.1 KB)
# train: Scanning /home/pham/Documents/SHSU/Researching/roaddamagedetector/RDD2022_3/China_Drone/labels/train.cache... 22184 images, 482 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 22666/22666 1.9Git/s 0.0s
# val: Fast image access ✅ (ping: 0.1±0.1 ms, read: 519.6±375.8 MB/s, size: 161.6 KB)
# val: Scanning /home/pham/Documents/SHSU/Researching/roaddamagedetector/RDD2022_3/China_MotorBike/labels/val.cache... 2181 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2181/2181 56.8Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 96 weight(decay=0.0), 105 weight(decay=0.0005), 104 bias(decay=0.0)
# Plotting labels to /home/pham/Documents/SHSU/Researching/roaddamagedetector/yolov11/runs/detect/yolo11s_p2p3p4p5/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/pham/Documents/SHSU/Researching/roaddamagedetector/yolov11/runs/detect/yolo11s_p2p3p4p5
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      11.3G      3.581      5.438      4.185         32        640: 2% ──────────── 14/709 1.1s/it 22.2s<12:43
