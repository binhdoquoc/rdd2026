# %%
import os
import torch
os.chdir("/home/mdptlab/roaddamagedetector/yolov11")
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO
model_name = "yolo11s_cap3p4p5"
# Build a YOLOv11l model from pretrained weight
model = YOLO(f"{model_name}.yaml")
model.info()
# Out:
# YOLO11s_cap3p4p5 summary: 197 layers, 9,494,432 parameters, 9,494,416 gradients, 21.8 GFLOPs
# (197, 9494432, 9494416, 21.7712128)

# %%
# Load pretrained weights
model = YOLO(f"{model_name}.yaml").load("yolo11s.pt")
# Out:
# Transferred 288/532 items from pretrained weights

# %%
# Training.
results = model.train(
   data='/home/pham/Documents/SHSU/Researching/roaddamagedetector/rddallcountriespotholesfortrainyolov11.yaml',
   imgsz=640,
   epochs=150,
   batch=32,
   name=model_name)
# Out:
# Ultralytics 8.4.60 🚀 Python-3.10.20 torch-2.5.1+cu121 CUDA:0 (NVIDIA RTX A4000, 15985MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/pham/Documents/SHSU/Researching/roaddamagedetector/rddallcountriespotholesfortrainyolov11.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=150, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s_cap3p4p5.yaml, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo11s_cap3p4p5, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=yolo11s.pt, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/pham/Documents/SHSU/Researching/roaddamagedetector/yolov11/runs/detect/yolo11s_cap3p4p5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1      3352  ultralytics.nn.modules.block.CoordAtt        [128, 32]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  21                  -1  1      6680  ultralytics.nn.modules.block.CoordAtt        [256, 32]
#  22                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  23            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  24                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  25                  -1  1     25648  ultralytics.nn.modules.block.CoordAtt        [512, 32]
#  26        [17, 21, 25]  1    820956  ultralytics.nn.modules.head.Detect           [4, 16, None, [128, 256, 512]]
# YOLO11s_cap3p4p5 summary: 197 layers, 9,465,020 parameters, 9,465,004 gradients, 21.6 GFLOPs
#
# Transferred 526/532 items from pretrained weights
# Freezing layer 'model.26.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1854.4±556.3 MB/s, size: 155.1 KB)
# train: Scanning /home/pham/Documents/SHSU/Researching/roaddamagedetector/RDD2022_3/China_Drone/labels/train.cache... 22184 images, 482 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 22666/22666 2.8Git/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1258.5±548.4 MB/s, size: 161.6 KB)
# val: Scanning /home/pham/Documents/SHSU/Researching/roaddamagedetector/RDD2022_3/China_MotorBike/labels/val.cache... 2181 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2181/2181 77.5Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 84 weight(decay=0.0), 97 weight(decay=0.0005), 99 bias(decay=0.0)
# Plotting labels to /home/pham/Documents/SHSU/Researching/roaddamagedetector/yolov11/runs/detect/yolo11s_cap3p4p5/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/pham/Documents/SHSU/Researching/roaddamagedetector/yolov11/runs/detect/yolo11s_cap3p4p5
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      7.81G      3.849      5.103      4.209         32        640: 2% ──────────── 11/709 1.5it/s 15.7s<7:51
